# %%
from dotenv import load_dotenv
# OPENAI_API_KEY 환경변수 설정

# import os
# api_key = os.getenv("env_key_name")

# load_dotenv(api_key=api_key)

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

ai_message.content
# Out:
# '인프런에는 다양한 주제와 분야의 강의가 있습니다. 프로그래밍, 디자인, 비즈니스, 언어, 자기계발 등 다양한 주제의 강의를 제공하고 있습니다. 또한 인기 강사들이 진행하는 실용적이고 유용한 강의들이 많이 있으니 원하는 분야나 주제에 맞는 강의를 찾아 수강할 수 있습니다. 에디터 picks, 베스트 스터디도 추천해 드립니다. 그 외에도 신규 강좌 업데이트 및 프로젝트 교육도 있으니 적합한 강의를 찾아보시기 바랍니다.'
